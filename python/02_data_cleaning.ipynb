# %%
# ===========================================
# Retail & E-Commerce Talent Pool Analysis
# 02 - Data Cleaning
# Author : Rinda Wahyu Lestari
# ===========================================

# %% [markdown]
# # Data Cleaning
#
# In this notebook, the dataset is cleaned by checking missing values,
# duplicate records, data types, and column consistency before analysis.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/retail_ecommerce_talent_pool.csv", sep=";")

# %%
df.isnull().sum()
# Out:
# candidate_id               0
# city                       0
# fresh_graduate_status      0
# skills                     0
# excel_skill                0
# sql_skill                  0
# python_skill               0
# power_bi_skill             0
# looker_studio_skill        0
# database_skill             0
# tableau_skill              0
# other_skills             637
# candidate_goals            0
# platform_source            0
# province                   0
# for_job                    0
# upskills                   0
# networking                 0
# switch_career              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# candidate_id              int64
# city                     object
# fresh_graduate_status    object
# skills                   object
# excel_skill               int64
# sql_skill                 int64
# python_skill              int64
# power_bi_skill            int64
# looker_studio_skill       int64
# database_skill            int64
# tableau_skill             int64
# other_skills             object
# candidate_goals          object
# platform_source          object
# province                 object
# for_job                   int64
# upskills                  int64
# networking                int64
# switch_career             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   candidate_id           681 non-null    int64
#  1   city                   681 non-null    object
#  2   fresh_graduate_status  681 non-null    object
#  3   skills                 681 non-null    object
#  4   excel_skill            681 non-null    int64
#  5   sql_skill              681 non-null    int64
#  6   python_skill           681 non-null    int64
#  7   power_bi_skill         681 non-null    int64
#  8   looker_studio_skill    681 non-null    int64
#  9   database_skill         681 non-null    int64
#  10  tableau_skill          681 non-null    int64
#  11  other_skills           44 non-null     object
#  12  candidate_goals        681 non-null    object
#  13  platform_source        681 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['candidate_id', 'city', 'fresh_graduate_status', 'skills',
#        'excel_skill', 'sql_skill', 'python_skill', 'power_bi_skill',
#        'looker_studio_skill', 'database_skill', 'tableau_skill',
#        'other_skills', 'candidate_goals', 'platform_source', 'province',
#        'for_job', 'upskills', 'networking', 'switch_career'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df["fresh_graduate_status"].unique()
# Out:
# array(['Ya', 'Tidak'], dtype=object)

# %%
df.to_csv(
    "../data/retail_ecommerce_talent_pool_clean.csv",
    index=False
)

# %%
df["province"].nunique()
# Out:
# 28

# %%
df["platform_source"].nunique()
# Out:
# 3

# %%
df["other_skills"].notna().sum()
# Out:
# 44

# %%
df["fresh_graduate_status"].value_counts()
# Out:
# fresh_graduate_status
# Ya       386
# Tidak    295
# Name: count, dtype: int64

# %%
df["for_job"].sum()
# Out:
# 450
